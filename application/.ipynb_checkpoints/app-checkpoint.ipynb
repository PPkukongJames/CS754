# %%
#!pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB 393.8 kB/s eta 0:00:40
#    ---------------------------------------- 0.1/15.4 MB 658.3 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/15.4 MB 722.1 kB/s eta 0:00:22
#     --------------------------------------- 0.3/15.4 MB 1.2 MB/s eta 0:00:13
#    - -------------------------------------- 0.4/15.4 MB 1.3 MB/s eta 0:00:12
#    - -------------------------------------- 0.4/15.4 MB 1.3 MB/s eta 0:00:12
#    - -------------------------------------- 0.5/15.4 MB 1.3 MB/s eta 0:00:12
#    - -------------------------------------- 0.6/15.4 MB 1.4 MB/s eta 0:00:11
#    - -------------------------------------- 0.6/15.4 MB 1.4 MB/s eta 0:00:11
#    - -------------------------------------- 0.7/15.4 MB 1.5 MB/s eta 0:00:10
# ...

# %%
from jwt_app import *

# %%
encode({
    'user':'root',
    'password':'Pk170943.'
})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 encode({
#       2     'user':'root',
#       3     'password':'Pk170943.'
#       4 })
#
# TypeError: PyJWT.encode() missing 1 required positional argument: 'key'

# %%
import mysql.connector

# %%
mysql.connector.connect(
  host="localhost",
  user="yourusername",
  password="Pk170943."
)
